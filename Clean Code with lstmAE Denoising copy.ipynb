# %% [markdown]
# # Setup

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import warnings
import torch
import torch.nn as nn
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns # visualization library
import matplotlib.pyplot as plt # visualization library
from plotly.offline import init_notebook_mode, iplot # plotly offline mode
import plotly.graph_objs as go # plotly graphical object


import src.data.timeseries_eda as eda 

init_notebook_mode(connected=True)
# ignore filters
warnings.filterwarnings("ignore") # if there is a warning after some codes, this will avoid us to see them.
plt.style.use('ggplot')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # config

# %%
symbol = 'EURUSD'

# %% [markdown]
# # EDA

# %%
market_data = pd.read_csv(f'data/{symbol}_1h.csv')
market_data.head()
# Out:
#    Unnamed: 0            open_time  open_bid  low_bid  high_bid  close_bid  \
# 0           0  2015-02-02 01:00:00   1.13082  1.13082   1.13157    1.13153
# 1           1  2015-02-02 02:00:00   1.13152  1.13135   1.13255    1.13179
# 2           2  2015-02-02 03:00:00   1.13180  1.13054   1.13180    1.13102
# 3           3  2015-02-02 04:00:00   1.13101  1.13084   1.13132    1.13084
# 4           4  2015-02-02 05:00:00   1.13085  1.13071   1.13134    1.13084
#
#    volume_bid  open_ask  low_ask  high_ask  close_ask  volume_ask  \
# 0     2712.48   1.13086  1.13086   1.13160    1.13156     2853.70
# 1     2935.13   1.13156  1.13136   1.13257    1.13181     2945.25
# 2     2610.78   1.13181  1.13057   1.13185    1.13103     2617.55
# 3     1723.14   1.13103  1.13088   1.13136    1.13088     1489.47
# 4     1966.10   1.13088  1.13073   1.13136    1.13085     1753.40
#
#             close_time  month  year
# 0  2015-02-02 02:00:00      2  2015
# 1  2015-02-02 03:00:00      2  2015
# 2  2015-02-02 04:00:00      2  2015
# 3  2015-02-02 05:00:00      2  2015
# 4  2015-02-02 06:00:00      2  2015

# %%
market_data['open_time'] = pd.to_datetime(market_data['open_time'])
market_data.set_index('open_time', inplace=True)
market_data.drop(columns='close_time', inplace=True)

# %%
#stationary = eda.Stationary(market_data)

#for feature in market_data.columns:
#    stationary.check(feature)
#    print('-'*20)

# %%
#stationary.check('close_ask')
#stationary.plot('close_ask')

# %%
#eda.plot_price_volume(market_data, kind = 'bid')

# %%
#eda.plot_candlestick(market_data, kind = 'bid')

# %%
#normality_checker = eda.Normality(market_data)
#list_of_features_to_be_normalized = []
#for col in market_data.columns:
#    if normality_checker.check(col):
#       continue
#    list_of_features_to_be_normalized.append(col)
#list_of_features_to_be_normalized

# %% [markdown]
# # Features Engineering

# %%
from src.data.feature_engineering import PercentageFeatureAdder, BollingerBandAdder, TargetAdder,Scalar

percentage_feature_adder = PercentageFeatureAdder(1)
bidbb_adder = BollingerBandAdder(kind = 'bid')
askbb_adder = BollingerBandAdder(kind = 'ask')


pipeline = [bidbb_adder, askbb_adder, percentage_feature_adder]

# %%
transformed = market_data.copy()
for idx , trans in enumerate(pipeline):
    print(f'Transformation number: {idx + 1}')
    transformed = trans.transform(transformed)
# Out:
# Transformation number: 1
# Transformation number: 2
# Transformation number: 3

# %%
ready_to_train_features = ['volume_bid',
 'volume_ask',
 'month',
 'bid_golden/death',
 'bid_standard_deviation',
 'bid_bollinger_touch',
 'ask_golden/death',
 'ask_standard_deviation',
 'ask_bollinger_touch',
 'hhpc_bid_1',
 'llpc_bid_1',
 'hhpc_bid_3',
 'llpc_bid_3',
 'hplpcp_bid_1',
 'hplpcp_bid_3',
 'hplpcp_bid_4',
 'vvpavg3_bid',
 'vvp3avg3_bid',
 'hc_bid',
 'ho_bid',
 'co_bid',
 'hhpc_ask_1',
 'llpc_ask_1',
 'hhpc_ask_3',
 'llpc_ask_3',
 'hplpcp_ask_1',
 'hplpcp_ask_3',
 'hplpcp_ask_4',
 'vvpavg3_ask',
 'vvp3avg3_ask',
 'hc_ask',
 'ho_ask',
 'co_ask']

# %%
#stationary_checker = eda.Stationary(transformed)
#normality_checker = eda.Normality(transformed)

#ready_to_train_features = []
#for col in transformed.columns:
#    if not stationary_checker.check(col) :
#       continue
#    ready_to_train_features.append(col)

#ready_to_train_features

# %%
target_adder = TargetAdder(step_number=1 , look_back_steps =2)
transformed
# Out:
#                      Unnamed: 0  open_bid  low_bid  high_bid  close_bid  \
# open_time
# 2015-02-03 06:00:00          29   1.13314  1.13260   1.13392    1.13387
# 2015-02-03 07:00:00          30   1.13387  1.13271   1.13475    1.13316
# 2015-02-03 08:00:00          31   1.13316  1.13216   1.13518    1.13243
# 2015-02-03 09:00:00          32   1.13244  1.13124   1.13437    1.13334
# 2015-02-03 10:00:00          33   1.13332  1.13317   1.13547    1.13504
# ...                         ...       ...      ...       ...        ...
# 2023-07-14 00:00:00       52651   1.12244  1.12217   1.12280    1.12237
# 2023-07-14 01:00:00       52652   1.12237  1.12134   1.12247    1.12229
# 2023-07-14 02:00:00       52653   1.12229  1.12221   1.12337    1.12336
# 2023-07-14 03:00:00       52654   1.12336  1.12311   1.12386    1.12337
# 2023-07-14 04:00:00       52655   1.12337  1.12337   1.12344    1.12343
#
#                      volume_bid  open_ask  low_ask  high_ask  close_ask  ...  \
# open_time                                                                ...
# 2015-02-03 06:00:00     3575.43   1.13316  1.13263   1.13395    1.13391  ...
# 2015-02-03 07:00:00     7018.44   1.13391  1.13274   1.13478    1.13319  ...
# 2015-02-03 08:00:00    11231.82   1.13320  1.13218   1.13521    1.13246  ...
# 2015-02-03 09:00:00    10326.65   1.13246  1.13127   1.13438    1.13340  ...
# 2015-02-03 10:00:00     7146.93   1.13340  1.13319   1.13549    1.13508  ...
# ...                         ...       ...      ...       ...        ...  ...
# 2023-07-14 00:00:00     6880.17   1.12248  1.12220   1.12283    1.12241  ...
# 2023-07-14 01:00:00    16004.12   1.12240  1.12136   1.12249    1.12233  ...
# 2023-07-14 02:00:00    19662.13   1.12232  1.12224   1.12341    1.12340  ...
# 2023-07-14 03:00:00    13582.36   1.12339  1.12314   1.12387    1.12340  ...
# 2023-07-14 04:00:00      101.18   1.12339  1.12339   1.12348    1.12346  ...
#
#                      hhpc_ask_3  llpc_ask_3  hplpcp_ask_1  hplpcp_ask_3  \
# open_time
# 2015-02-03 06:00:00   -0.000564   -0.000194      0.000980      0.001536
# 2015-02-03 07:00:00    0.001288    0.000168      0.001164      0.000679
# 2023-07-14 04:00:00                   -0.098009        1.12232        1.12229
#
# [52567 rows x 53 columns]

# %%
normality_checker = eda.Normality(transformed.iloc[-2000:])

# %%
normality_checker.check('high_bid_change_rate_target')
# Out:
# False

# %%
normality_checker.plot('high_bid_change_rate_target')

# %%
transformed['high_bid_change_rate_target'].hist()
# Out:
# <Axes: >

# %%
# add retransform method to the target adder (goining from target to abs price) dobe 
# Scaler(Tranformer) , transform and retransform , scale a set of input features (fit, transform, retransform) done 
# Dataset class for your Pytorch model  
# train your model and try to refactor the training code to be re-usable
# evaluatin of models think about adding metrics and plots 
# move the Wavelet to the feature eng part and make it as a Tranformer: implementation done 
#    * denoise input data then make features 
#    * denoise the features directly 
# prepare in the evalutaion part a way to copmare the models performance 
# add the mlp auto-encoder denoiser and try to copmare results ( no-denoising vs wavelet vs auto-encoder)

# %%
transformed.columns
# Out:
# Index(['Unnamed: 0', 'open_bid', 'low_bid', 'high_bid', 'close_bid',
#        'volume_bid', 'open_ask', 'low_ask', 'high_ask', 'close_ask',
#        'volume_ask', 'month', 'year', 'bid_golden/death',
#        'bid_standard_deviation', 'bid_upper_band', 'bid_lower_band',
#        'bid_middle_band', 'bid_bollinger_touch', 'ask_golden/death',
#        'ask_standard_deviation', 'ask_upper_band', 'ask_lower_band',
#        'ask_middle_band', 'ask_bollinger_touch', 'hhpc_bid_1', 'llpc_bid_1',
#        'hhpc_bid_3', 'llpc_bid_3', 'hplpcp_bid_1', 'hplpcp_bid_3',
#        'hplpcp_bid_4', 'vvpavg3_bid', 'vvp3avg3_bid', 'hc_bid', 'ho_bid',
#        'co_bid', 'hhpc_ask_1', 'llpc_ask_1', 'hhpc_ask_3', 'llpc_ask_3',
#        'hplpcp_ask_1', 'hplpcp_ask_3', 'hplpcp_ask_4', 'vvpavg3_ask',
#        'vvp3avg3_ask', 'hc_ask', 'ho_ask', 'co_ask',
#        'high_bid_change_rate_target', 'low_ask_change_rate_target',
#        'last_open_ask', 'last_open_bid'],
#       dtype='object')

# %%
feature=ready_to_train_features
target=['high_bid_change_rate_target', 'low_ask_change_rate_target']

# %% [markdown]
# # Models Training

# %%
from src.data.dataloader import CreateDataset

my_dataset = CreateDataset(transformed, 10, feature, target)

train_data, valid_data, test_data = my_dataset.dataset_split(0.294,0.084)

# %%
from src.data.feature_engineering import Scalar
scalar = Scalar()

# %%
#after denoise, recreate 
my_dataset = CreateDataset(transformed, 10, feature, target)

train_data, valid_data, test_data = my_dataset.dataset_split(0.294,0.084)
train_data[feature] = scalar.fit_transform(train_data[feature]) 
valid_data[feature] = scalar.transform(valid_data[feature])
test_data[feature] = scalar.transform(test_data[feature])

train_dataset = my_dataset.create_dataset(train_data)
valid_dataset = my_dataset.create_dataset(valid_data)
test_dataset = my_dataset.create_dataset(test_data)

train_loader = my_dataset.create_loader(train_dataset, 128)
valid_loader = my_dataset.create_loader(valid_dataset, 128)
test_loader = my_dataset.create_loader(test_dataset, 128)

# %%
#lstm Autoencoder

from src.models.autoencoder import LSTMAutoencoderTrainer, LSTMAutoencoder
input_size = len(feature)
hidden_size = input_size//2

model = LSTMAutoencoder(input_size, hidden_size)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = nn.MSELoss()
trainer = LSTMAutoencoderTrainer(model, optimizer, criterion)


num_epochs = 200
trainer.fit(train_loader, num_epochs)


decoded_data,idx = trainer.transform(train_loader)
# Out:
# Epoch [10/200], Loss: 0.012248233228092431
# Epoch [20/200], Loss: 0.0014700356840648965
# Epoch [30/200], Loss: 0.0011557870204228493
# Epoch [40/200], Loss: 0.0010451124925907607
# Epoch [50/200], Loss: 0.0009847927307760074
# Epoch [60/200], Loss: 0.000907329883489183
# Epoch [70/200], Loss: 0.0007849531642705188
# Epoch [80/200], Loss: 0.000610312550548997
# Epoch [90/200], Loss: 0.00038969219178852654
# Epoch [100/200], Loss: 0.0002190508749890796
# Epoch [110/200], Loss: 0.00017928328438188146
# Epoch [120/200], Loss: 0.00015656822503729018
# Epoch [130/200], Loss: 0.0001368281489817491
# Epoch [140/200], Loss: 0.00011868450131657937
# Epoch [150/200], Loss: 0.00010762693176147309
# Epoch [160/200], Loss: 9.633721935031758e-05
# Epoch [170/200], Loss: 8.696439851973992e-05
# Epoch [180/200], Loss: 7.909912911685524e-05
# Epoch [190/200], Loss: 7.267725309390016e-05
# Epoch [200/200], Loss: 6.712333140868054e-05

# %%
train_data=train_data.iloc[10:]
train_data[feature]=decoded_data[:,-1,:]

train_dataset = my_dataset.create_dataset(train_data)
train_loader = my_dataset.create_loader(train_dataset, 128)

# %%
DEVICE = 'cuda' 
BATCH_SIZE = 32 
MAX_WAIT = 3
EPOCHS = 25 
LR = 1e-4

# %%
from src.models import nn_trainer, lstm_forecaster
import torch
import torch.nn as nn
import torch.optim.lr_scheduler as lr_scheduler

rnn_model = lstm_forecaster.RNN(
    input_size = len(feature),
    output_size = 2 
    )

loss_fn = nn.MSELoss() 
optimizer = torch.optim.AdamW(params = rnn_model.parameters() , lr = LR)
scheduler = lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

# %%
train_rnn = nn_trainer.Trainer(rnn_model , optimizer , train_loader , valid_loader, EPOCHS, MAX_WAIT, DEVICE, loss_fn,scheduler)
train_losses , valid_losses = train_rnn.fit()
# Out:
#   0%|          | 0/121 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
# EPOCH = 0
# train_loss = 0.047815916905841555
# valid_loss = 0.022131083346903325
#   0%|          | 0/121 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
# EPOCH = 1
# train_loss = 0.04363777065911323
# valid_loss = 0.02162971185254199
#   0%|          | 0/121 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
# EPOCH = 2
# train_loss = 0.04345928936088381
# valid_loss = 0.02164120836449521
#   0%|          | 0/121 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
# EPOCH = 3
# train_loss = 0.043451201932674106
# valid_loss = 0.02164332140237093
#   0%|          | 0/121 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
# EPOCH = 4
# train_loss = 0.04344850773961583
# valid_loss = 0.021645183994301726
#   0%|          | 0/121 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
# EPOCH = 5
# train_loss = 0.04344713734078013
# valid_loss = 0.02164668533951044
# EARLY STOPPING AT EPOCH = 5

# %% [markdown]
# # Evaluation

# %%
from src.eval.metrics import ForecastEval

# %%
indexes , high_bid_predictions, low_ask_predictions = train_rnn.predict(test_loader)
indexes_datetime = pd.to_datetime(indexes)

# %%
predictions = pd.DataFrame(
    data = {
        'high_bid_change_rate_target': high_bid_predictions,
        'low_ask_change_rate_target': low_ask_predictions,
    },
    index = indexes_datetime
)   
predictions[['last_open_ask','last_open_bid']] = test_data[['last_open_ask','last_open_bid']]
predictions.head()
# Out:
#                      high_bid_change_rate_target  low_ask_change_rate_target  \
# 2018-04-11 21:00:00                     0.067005                    0.064544
# 2018-04-11 22:00:00                     0.066911                    0.064572
# 2018-04-11 23:00:00                     0.066775                    0.064612
# 2018-04-12 00:00:00                     0.066721                    0.064624
# 2018-04-12 01:00:00                     0.066890                    0.064575
#
#                      last_open_ask  last_open_bid
# 2018-04-11 21:00:00        1.23627        1.23625
# 2018-04-11 22:00:00        1.23618        1.23615
# 2018-04-11 23:00:00        1.23681        1.23664
# 2018-04-12 00:00:00        1.23678        1.23671
# 2018-04-12 01:00:00        1.23703        1.23699

# %%
predictions = target_adder.retransform(predictions)

# %%
orginal_test_data = market_data[['open_ask','open_bid','low_ask','high_bid','close_ask','close_bid']].loc[predictions.index]

# %%
(predictions['high_bid'] - orginal_test_data['high_bid']).plot()
# Out:
# <Axes: >

# %%
evaluator= ForecastEval(orginal_data= orginal_test_data , predicted_data = predictions)
evaluator.run_evaluation()
# Out:
# Position Accuracy: 2.43%
# ABS error:  28752.0632322148

# %%
(orginal_test_data['high_bid']>predictions['high_bid']).mean()*100
# Out:
# 38.86747430249633

# %%
(orginal_test_data['low_ask']>predictions['low_ask']).mean()*100
# Out:
# 59.95778267254038

# %%
orginal_test_data.to_csv('data/predictions/original_test_data_with_lstmAE.csv')
predictions.to_csv('data/predictions/predictions_with_lstmAE.csv')

# %% [markdown]
# # Anomaly Detection: Autoencoder vs. Prediction

# %%
feature=['high_bid_change_rate_target', 'low_ask_change_rate_target']
target=['high_bid_change_rate_target', 'low_ask_change_rate_target']
# decoded_test,idx = trainer.transform(test_loader)

# %%
my_dataset = CreateDataset(transformed, 10, feature, target)

train_data, valid_data, test_data = my_dataset.dataset_split(0.294,0.084)


train_dataset = my_dataset.create_dataset(train_data)
valid_dataset = my_dataset.create_dataset(valid_data)
test_dataset = my_dataset.create_dataset(test_data)

train_loader = my_dataset.create_loader(train_dataset, 128)
valid_loader = my_dataset.create_loader(valid_dataset, 128)
test_loader = my_dataset.create_loader(test_dataset, 128)

# %%
from src.models.autoencoder import LSTMAutoencoderTrainer, LSTMAutoencoder
input_size = len(feature)
hidden_size = 2
model = LSTMAutoencoder(input_size, hidden_size)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = nn.MSELoss()
trainer = LSTMAutoencoderTrainer(model, optimizer, criterion)


num_epochs = 200
trainer.fit(train_loader, num_epochs)


result,idx = trainer.transform(test_loader)
# Out:
# Epoch [10/200], Loss: 1.8029743421357125
# Epoch [20/200], Loss: 1.0923790982342325
# Epoch [30/200], Loss: 0.7224231889704242
# Epoch [40/200], Loss: 0.5255746551629272
# Epoch [50/200], Loss: 0.462645494586468
# Epoch [60/200], Loss: 0.42875156614536536
# Epoch [70/200], Loss: 0.4066908340773807
# Epoch [80/200], Loss: 0.3925420460054738
# Epoch [90/200], Loss: 0.3832312390622974
# Epoch [100/200], Loss: 0.3767776809181669
# Epoch [110/200], Loss: 0.37212702510441886
# Epoch [120/200], Loss: 0.36862382447543496
# Epoch [130/200], Loss: 0.365855207277491
# Epoch [140/200], Loss: 0.36357072320606676
# Epoch [150/200], Loss: 0.36162087433876877
# Epoch [160/200], Loss: 0.3599145077041612
# Epoch [170/200], Loss: 0.3583911542482383
# Epoch [180/200], Loss: 0.3570043455456471
# Epoch [190/200], Loss: 0.3557147237697791
# Epoch [200/200], Loss: 0.35449295782018453

# %%
decoded_data=result[:,-1,:]
decoded_data
# Out:
# tensor([[-0.0123,  0.0924],
#         [ 0.0588, -0.0135],
#         [ 0.0731, -0.0388],
#         ...,
#         [-0.0022,  0.0933],
#         [ 0.0773,  0.0169],
#         [ 0.1274, -0.0635]])

# %%
idx = pd.Series(idx)

idx= idx.shift(1)

indexes_datetime = pd.to_datetime(idx)
indexes_datetime
# Out:
# 0                       NaT
# 1       2018-04-11 21:00:00
# 2       2018-04-11 22:00:00
# 3       2018-04-11 23:00:00
# 4       2018-04-12 00:00:00
#                 ...
# 32683   2023-07-13 23:00:00
# 32684   2023-07-14 00:00:00
# 32685   2023-07-14 01:00:00
# 32686   2023-07-14 02:00:00
# 32687   2023-07-14 03:00:00
# Length: 32688, dtype: datetime64[ns]

# %%
decoded_data = pd.concat([pd.DataFrame({'datetime': indexes_datetime}),
                           pd.DataFrame(decoded_data.numpy(), columns=['high_bid_change_rate_target',
        'low_ask_change_rate_target'])
], axis=1)
decoded_data.index = indexes_datetime

print(decoded_data)
# Out:
#                                datetime  high_bid_change_rate_target  \
# NaT                                 NaT                    -0.012299
# 2018-04-11 21:00:00 2018-04-11 21:00:00                     0.058849
# 2018-04-11 22:00:00 2018-04-11 22:00:00                     0.073131
# 2018-04-11 23:00:00 2018-04-11 23:00:00                     0.034224
# 2018-04-12 00:00:00 2018-04-12 00:00:00                     0.094003
# ...                                 ...                          ...
# 2023-07-13 23:00:00 2023-07-13 23:00:00                     0.044831
# 2023-07-14 00:00:00 2023-07-14 00:00:00                     0.036127
# 2023-07-14 01:00:00 2023-07-14 01:00:00                    -0.002208
# 2023-07-14 02:00:00 2023-07-14 02:00:00                     0.077342
# 2023-07-14 03:00:00 2023-07-14 03:00:00                     0.127400
#
#                      low_ask_change_rate_target
# NaT                                    0.092403
# 2018-04-11 21:00:00                   -0.013532
# 2018-04-11 22:00:00                   -0.038843
# 2018-04-11 23:00:00                   -0.009775
# 2018-04-12 00:00:00                   -0.033514
# ...                                         ...
# 2023-07-14 01:00:00                    0.093330        1.12250        1.12244
# 2023-07-14 02:00:00                    0.016943        1.12248        1.12244
# 2023-07-14 03:00:00                   -0.063550        1.12240        1.12237
#
#                      high_bid   low_ask
# NaT                       NaN       NaN
# 2018-04-11 21:00:00  1.236997  1.236417
# 2018-04-11 22:00:00  1.237084  1.236630
# 2018-04-11 23:00:00  1.237233  1.236761
# 2018-04-12 00:00:00  1.237943  1.237124
# ...                       ...       ...
# 2023-07-13 23:00:00  1.122953  1.122422
# 2023-07-14 00:00:00  1.122796  1.122195
# 2023-07-14 01:00:00  1.122475  1.121392
# 2023-07-14 02:00:00  1.123348  1.122250
# 2023-07-14 03:00:00  1.123830  1.123083
#
# [32688 rows x 7 columns]

# %%
predictions
# Out:
#                      high_bid_change_rate_target  low_ask_change_rate_target  \
# 2018-04-11 21:00:00                     0.067005                    0.064544
# 2018-04-11 22:00:00                     0.066911                    0.064572
# 2018-04-11 23:00:00                     0.066775                    0.064612
# 2018-04-12 00:00:00                     0.066721                    0.064624
# 2018-04-12 01:00:00                     0.066890                    0.064575
# ...                                          ...                         ...
# 2023-07-14 00:00:00                     0.066775                    0.064619
# 2023-07-14 01:00:00                     0.066841                    0.064598
# 2023-07-14 02:00:00                     0.067108                    0.064523
# 2023-07-14 03:00:00                     0.067304                    0.064469
# 2023-07-14 04:00:00                     0.067287                    0.064464
#
#                      last_open_ask  last_open_bid  high_bid   low_ask
# 2018-04-11 21:00:00        1.23627        1.23625  1.237098  1.235452
# 2018-04-11 22:00:00        1.23618        1.23615  1.237007  1.235352
# 2018-04-11 23:00:00        1.23681        1.23664  1.237636  1.235841
# 2018-04-12 00:00:00        1.23678        1.23671  1.237605  1.235911
# 2018-04-12 01:00:00        1.23703        1.23699  1.237857  1.236191
# ...                            ...            ...       ...       ...
# 2023-07-14 00:00:00        1.12239        1.12238  1.123140  1.121655
# 2023-07-14 01:00:00        1.12250        1.12244  1.123250  1.121715
# 2023-07-14 02:00:00        1.12248        1.12244  1.123233  1.121716
# 2023-07-14 03:00:00        1.12240        1.12237  1.123155  1.121646
# 2023-07-14 04:00:00        1.12232        1.12229  1.123075  1.121567
#
# [32688 rows x 6 columns]

# %%
from src.eval.plots import  plot_comparison
plot_comparison(predictions, orginal_test_data, threshold=0.005,column_name='high_bid')

# %%
(decoded_data['high_bid'] - orginal_test_data['high_bid']).plot()
# Out:
# <Axes: >

# %%
plot_comparison(decoded_data,orginal_test_data,threshold=0.005,column_name='high_bid')

# %%
#Detect abnormal period
from src.eval.plots import plot_abnormal_period 
plot_abnormal_period(predictions, orginal_test_data, threshold = 0.005)
# Out:
# [(Timestamp('2020-06-04 12:00:00'), 5), (Timestamp('2022-09-28 14:00:00'), 5)]

# %%
from src.eval.plots import check_overlap
check_overlap(predictions, decoded_data, orginal_test_data, threshold = 0.005,column_name='high_bid')
# Out:
# Index Overlap: DatetimeIndex(['2022-09-13 13:00:00', '2022-10-13 15:00:00',
#                '2022-11-10 13:00:00', '2022-11-10 14:00:00',
#                '2022-11-10 15:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# # Market Classification

# %%
def split_market(predictions, orginal_test_data, abnormal_indices):
    normal_market_indices = predictions.index.difference(abnormal_indices)
    
    normal_market_predictions = predictions.loc[normal_market_indices]
    normal_market_orginal_data = orginal_test_data.loc[normal_market_indices]
    
    abnormal_market_predictions = predictions.loc[abnormal_indices]
    abnormal_market_orginal_data = orginal_test_data.loc[abnormal_indices]
    
    return normal_market_predictions, normal_market_orginal_data, abnormal_market_predictions, abnormal_market_orginal_data

# %%
from src.eval.plots import check_abnormal_indices,abnormal_interval
abnormal_indices=check_abnormal_indices(predictions, orginal_test_data, threshold=0.005,column_name='high_bid')
abnormal_period = abnormal_interval(predictions, abnormal_indices, 1)
abnormal_period
# Out:
# [DatetimeIndex(['2018-04-26 14:00:00', '2018-04-26 15:00:00',
#                 '2018-04-26 16:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2018-04-26 15:00:00', '2018-04-26 16:00:00',
#                 '2018-04-26 17:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2018-05-10 11:00:00', '2018-05-10 12:00:00',
#                 '2018-05-10 13:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2018-05-15 12:00:00', '2018-05-15 13:00:00',
#                 '2018-05-15 14:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2018-05-16 10:00:00', '2018-05-16 11:00:00',
#                 '2018-05-16 12:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2018-05-22 08:00:00', '2018-05-22 09:00:00',
#                 '2018-05-22 10:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2018-05-29 07:00:00', '2018-05-29 08:00:00',
#                 '2018-05-29 09:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2018-05-30 06:00:00', '2018-05-30 07:00:00',
#                 '2018-05-30 08:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2018-06-05 15:00:00', '2018-06-05 16:00:00',
#                 '2018-06-05 17:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2018-06-05 16:00:00', '2018-06-05 17:00:00',
#                 '2018-06-05 18:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2018-06-05 17:00:00', '2018-06-05 18:00:00',
#                 '2018-06-05 19:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2018-06-14 11:00:00', '2018-06-14 12:00:00',
#                 '2018-06-14 13:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2018-06-14 12:00:00', '2018-06-14 13:00:00',
#                 '2018-06-14 14:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2018-06-14 13:00:00', '2018-06-14 14:00:00',
#                 '2018-06-14 15:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2018-06-21 11:00:00', '2018-06-21 12:00:00',
#                 '2018-06-21 13:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2018-06-21 12:00:00', '2018-06-21 13:00:00',
#                 '2018-06-21 14:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2018-06-21 13:00:00', '2018-06-21 14:00:00',
#                 '2018-06-21 15:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2018-06-22 06:00:00', '2018-06-22 07:00:00',
#                 '2018-06-22 08:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2018-06-29 01:00:00', '2018-06-29 02:00:00',
#                 '2018-06-29 03:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2018-06-29 02:00:00', '2018-06-29 03:00:00',
#                 '2018-06-29 04:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2018-06-29 03:00:00', '2018-06-29 04:00:00',
#                 '2018-06-29 05:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2018-07-19 16:00:00', '2018-07-19 17:00:00',
#                 '2018-07-19 18:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2018-07-19 17:00:00', '2018-07-19 18:00:00',
#                 '2018-07-19 19:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2018-07-20 11:00:00', '2018-07-20 12:00:00',
#                 '2018-07-20 13:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2018-07-20 12:00:00', '2018-07-20 13:00:00',
#                 '2018-07-20 14:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2018-07-20 13:00:00', '2018-07-20 14:00:00',
#                 '2018-07-20 15:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2018-07-25 18:00:00', '2018-07-25 19:00:00',
#                 '2018-07-25 20:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['
00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2019-01-11 15:00:00', '2019-01-11 16:00:00',
#                 '2019-01-11 17:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2019-01-15 16:00:00', '2019-01-15 17:00:00',
#                 '2019-01-15 18:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2019-01-15 17:00:00', '2019-01-15 18:00:00',
#                 '2019-01-15 19:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2019-01-24 16:00:00', '2019-01-24 17:00:00',
#                 '2019-01-24 18:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2019-01-24 17:00:00', '2019-01-24 18:00:00',
#                 '2019-01-24 19:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2019-01-25 14:00:00', '2019-01-25 15:00:00',
#                 '2019-01-25 16:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2019-01-30 18:00:00', '2019-01-30 19:00:00',
#                 '2019-01-30 20:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2019-01-30 19:00:00', '2019-01-30 20:00:00',
#                 '2019-01-30 21:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2019-01-30 20:00:00', '2019-01-30 21:00:00',
#                 '2019-01-30 22:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2019-03-07 13:00:00', '2019-03-07 14:00:00',
#                 '2019-03-07 15:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2019-03-07 14:00:00', '2019-03-07 15:00:00',
#                 '2019-03-07 16:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2019-03-20 17:00:00', '2019-03-20 18:00:00',
#                 '2019-03-20 19:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2019-03-20 18:00:00', '2019-03-20 19:00:00',
#                 '2019-03-20 20:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2019-03-20 19:00:00', '2019-03-20 20:00:00',
#                 '2019-03-20 21:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2019-03-22 08:00:00', '2019-03-22 09:00:00',
#                 '2019-03-22 10:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2019-03-22 09:00:00', '2019-03-22 10:00:00',
#                 '2019-03-22 11:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2019-05-01 19:00:00', '2019-05-01 20:00:00',
#                 '2019-05-01 21:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2019-05-09 13:00:00', '2019-05-09 14:00:00',
#                 '2019-05-09 15:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2019-06-06 11:00:00', '2019-06-06 12:00:00',
#                 '2019-06-06 13:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2019-06-06 12:00:00', '2019-06-06 13:00:00',
#                 '2019-06-06 14:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2019-06-07 11:00:00', '2019-06-07 12:00:00',
#                 '2019-06-07 13:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2019-06-07 12:00:00', '2019-06-07 13:00:00',
#                 '2019-06-07 14:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2019-06-07 13:00:00', '2019-06-07 14:00:00',
#                 '2019-06-07 15:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2019-06-18 08:00:00', '2019-06-18 09:00:00',
#                 '2019-06-18 10:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2019-07-25 13:00:00', '2019-07-25 14:00:00',
#                 '2019-07-25 15:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2019-07-31 19:00:00', '2019-07-31 20:00:00',
#                 '2019-07-31 21:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2019-08-23 13:00:00', '2019-08-23 14:00:00',
#                 '2019-08-23 15:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2019-08-23 14:00:00', '2019-08-23 15:00:00',
#                 '2019-08-23 16:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2019-08-23 15:00:00', '2019-08-23 16:00:00',
#                 '2019-08-23 17:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2019-08-30 15:00:00', '2019-08-30 16:00:00',
#                 '2019-08-30 17:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2019-09-12 11:00:00', '2019-09-12 12:00:00',
#                 '2019-09-12 13:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2019-09-12 13:00:00', '2019-09-12 14:00:00',
#                 '2019-09-12 15:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2019-09-12 14:00:00', '2019-09-12 15:00:00',
#                 '2019-09-12 16:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2019-10-17 08:00:00', '2019-10-17 09:00:00',
#                 '2019-10-17 10:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2019-10-24 14:00:00', '2019-10-24 15:00:00',
#                 '2019-10-24 16:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2019-12-02 14:00:00', '2019-12-02 15:00:00',
#                 '2019-12-02 16:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2019-12-02 15:00:00', '2019-12-02 16:00:00',
#                 '2019-12-02 17:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['
00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2023-04-10 13:00:00', '2023-04-10 14:00:00',
#                 '2023-04-10 15:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2023-04-12 11:00:00', '2023-04-12 12:00:00',
#                 '2023-04-12 13:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2023-04-12 12:00:00', '2023-04-12 13:00:00',
#                 '2023-04-12 14:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2023-04-12 13:00:00', '2023-04-12 14:00:00',
#                 '2023-04-12 15:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2023-04-14 15:00:00', '2023-04-14 16:00:00',
#                 '2023-04-14 17:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2023-04-28 13:00:00', '2023-04-28 14:00:00',
#                 '2023-04-28 15:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2023-04-28 14:00:00', '2023-04-28 15:00:00',
#                 '2023-04-28 16:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2023-05-01 14:00:00', '2023-05-01 15:00:00',
#                 '2023-05-01 16:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2023-05-01 15:00:00', '2023-05-01 16:00:00',
#                 '2023-05-01 17:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2023-05-02 15:00:00', '2023-05-02 16:00:00',
#                 '2023-05-02 17:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2023-05-10 13:00:00', '2023-05-10 14:00:00',
#                 '2023-05-10 15:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2023-06-15 13:00:00', '2023-06-15 14:00:00',
#                 '2023-06-15 15:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2023-06-15 14:00:00', '2023-06-15 15:00:00',
#                 '2023-06-15 16:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2023-06-15 15:00:00', '2023-06-15 16:00:00',
#                 '2023-06-15 17:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2023-06-23 08:00:00', '2023-06-23 09:00:00',
#                 '2023-06-23 10:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2023-06-23 09:00:00', '2023-06-23 10:00:00',
#                 '2023-06-23 11:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2023-06-29 13:00:00', '2023-06-29 14:00:00',
#                 '2023-06-29 15:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2023-06-30 13:00:00', '2023-06-30 14:00:00',
#                 '2023-06-30 15:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2023-06-30 14:00:00', '2023-06-30 15:00:00',
#                 '2023-06-30 16:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2023-07-07 14:00:00', '2023-07-07 15:00:00',
#                 '2023-07-07 16:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2023-07-12 13:00:00', '2023-07-12 14:00:00',
#                 '2023-07-12 15:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2023-07-12 14:00:00', '2023-07-12 15:00:00',
#                 '2023-07-12 16:00:00'],
#                dtype='datetime64[ns]', freq=None),
#  DatetimeIndex(['2023-07-12 15:00:00', '2023-07-12 16:00:00',
#                 '2023-07-12 17:00:00'],
#                dtype='datetime64[ns]', freq=None)]

# %%
normal_predictions, normal_orginal_data, abnormal_predictions, abnormal_orginal_data = split_market(predictions, orginal_test_data, abnormal_indices)

# %%
#normal market
from src.eval.forecast_features_adder import ForecastsAggergator, ForecastMetricsAdder
from src.eval.evaluation import merge_predictions_with_original

normal_merged= merge_predictions_with_original(normal_predictions, normal_orginal_data)

aggregator = ForecastsAggergator(quantiles=[0.5])
normal_merged = aggregator.transform(normal_merged)

normal_merged.reset_index(drop=False, inplace=True)
normal_merged.rename(columns={'index': 'open_time'}, inplace=True)

metricsadder=ForecastMetricsAdder(quantiles=[0.5])
normal_metric=metricsadder._add_metrics(normal_merged)
normal_metric
# Out:
#                 open_time  high_q50_error  high_q50_abs_error  \
# 0     2018-04-11 21:00:00        0.000058            0.000058
# 1     2018-04-11 22:00:00       -0.000103            0.000103
# 2     2018-04-11 23:00:00        0.000406            0.000406
# 3     2018-04-12 00:00:00       -0.000365            0.000365
# 4     2018-04-12 01:00:00        0.000037            0.000037
# ...                   ...             ...                 ...
# 32046 2023-07-14 00:00:00        0.000340            0.000340
# 32047 2023-07-14 01:00:00        0.000780            0.000780
# 32048 2023-07-14 02:00:00       -0.000137            0.000137
# 32049 2023-07-14 03:00:00       -0.000705            0.000705
# 32050 2023-07-14 04:00:00       -0.000365            0.000365
#
#        high_q50_pct_error  high_q50_abs_pct_error  high_q50_accuracy  \
# 0                     NaN                     NaN                  0
# 1               -0.008322                0.008322                  1
# 2                0.032813                0.032813                  0
# 3               -0.029483                0.029483                  1
# 4                0.003026                0.003026                  1
# ...                   ...                     ...                ...
# 32046            0.030246                0.030246                  0
# 32047            0.069512                0.069512                  0
# 32048           -0.012184                0.012184                  1
# 32049           -0.062715                0.062715                  1
# 32050           -0.032473                0.032473                  1
#
#        low_q50_error  low_q50_abs_error  low_q50_pct_error  \
# 0           0.001018           0.001018                NaN
# 1           0.001358           0.001358           0.109819
# 2           0.000949           0.000949           0.076716
# 3           0.001269           0.001269           0.102591
# 4           0.000569           0.000569           0.045963
# ...              ...                ...                ...
# 32046       0.000545           0.000545           0.048578
# 32047      -0.000355           0.000355          -0.031626
# 32048       0.000524           0.000524           0.046708
# 32049       0.001494           0.001494           0.132955
# 32050       0.001823           0.001823           0.162316
#
#        low_q50_abs_pct_error  low_q50_accuracy
# 0                        NaN                 0
# 1                   0.109819                 0
# 2                   0.076716                 0
# 3                   0.102591                 0
# 4                   0.045963                 0
# ...                      ...               ...
# 32046               0.048578                 0
# 32047               0.031626                 1
# 32048               0.046708                 0
# 32049               0.132955                 0
# 32050               0.162316                 0
#
# [32051 rows x 11 columns]

# %%
#general market
general_merged= merge_predictions_with_original(predictions, orginal_test_data)

aggregator = ForecastsAggergator(quantiles=[0.5])
general_merged = aggregator.transform(general_merged)

general_merged.reset_index(drop=False, inplace=True)
general_merged.rename(columns={'index': 'open_time'}, inplace=True)

metricsadder=ForecastMetricsAdder(quantiles=[0.5])
general_metric=metricsadder._add_metrics(general_merged)
general_metric
# Out:
#                 open_time  high_q50_error  high_q50_abs_error  \
# 0     2018-04-11 21:00:00        0.000058            0.000058
# 1     2018-04-11 22:00:00       -0.000103            0.000103
# 2     2018-04-11 23:00:00        0.000406            0.000406
# 3     2018-04-12 00:00:00       -0.000365            0.000365
# 4     2018-04-12 01:00:00        0.000037            0.000037
# ...                   ...             ...                 ...
# 32683 2023-07-14 00:00:00        0.000340            0.000340
# 32684 2023-07-14 01:00:00        0.000780            0.000780
# 32685 2023-07-14 02:00:00       -0.000137            0.000137
# 32686 2023-07-14 03:00:00       -0.000705            0.000705
# 32687 2023-07-14 04:00:00       -0.000365            0.000365
#
#        high_q50_pct_error  high_q50_abs_pct_error  high_q50_accuracy  \
# 0                     NaN                     NaN                  0
# 1               -0.008322                0.008322                  1
# 2                0.032813                0.032813                  0
# 3               -0.029483                0.029483                  1
# 4                0.003026                0.003026                  1
# ...                   ...                     ...                ...
# 32683            0.030246                0.030246                  0
# 32684            0.069512                0.069512                  0
# 32685           -0.012184                0.012184                  1
# 32686           -0.062715                0.062715                  1
# 32687           -0.032473                0.032473                  1
#
#        low_q50_error  low_q50_abs_error  low_q50_pct_error  \
# 0           0.001018           0.001018                NaN
# 1           0.001358           0.001358           0.109819
# 2           0.000949           0.000949           0.076716
# 3           0.001269           0.001269           0.102591
# 4           0.000569           0.000569           0.045963
# ...              ...                ...                ...
# 32683       0.000545           0.000545           0.048578
# 32684      -0.000355           0.000355          -0.031626
# 32685       0.000524           0.000524           0.046708
# 32686       0.001494           0.001494           0.132955
# 32687       0.001823           0.001823           0.162316
#
#        low_q50_abs_pct_error  low_q50_accuracy
# 0                        NaN                 0
# 1                   0.109819                 0
# 2                   0.076716                 0
# 3                   0.102591                 0
# 4                   0.045963                 0
# ...                      ...               ...
# 32683               0.048578                 0
# 32684               0.031626                 1
# 32685               0.046708                 0
# 32686               0.132955                 0
# 32687               0.162316                 0
#
# [32688 rows x 11 columns]

# %%
#abnormal market
abnormal_merged= merge_predictions_with_original(abnormal_predictions, abnormal_orginal_data)

aggregator = ForecastsAggergator(quantiles=[0.5])
abnormal_merged = aggregator.transform(abnormal_merged)

abnormal_merged.reset_index(drop=False, inplace=True)
abnormal_merged.rename(columns={'index': 'open_time'}, inplace=True)

metricsadder=ForecastMetricsAdder(quantiles=[0.5])
abnormal_metric=metricsadder._add_metrics(abnormal_merged)
abnormal_metric
# Out:
#               open_time  high_q50_error  high_q50_abs_error  \
# 0   2018-04-26 15:00:00        0.008797            0.008797
# 1   2018-04-26 16:00:00        0.005294            0.005294
# 2   2018-05-10 12:00:00       -0.005159            0.005159
# 3   2018-05-15 13:00:00        0.007375            0.007375
# 4   2018-05-16 11:00:00        0.005060            0.005060
# ..                  ...             ...                 ...
# 632 2023-06-30 15:00:00       -0.006992            0.006992
# 633 2023-07-07 15:00:00       -0.005427            0.005427
# 634 2023-07-12 14:00:00       -0.007130            0.007130
# 635 2023-07-12 15:00:00       -0.009829            0.009829
# 636 2023-07-12 16:00:00       -0.005836            0.005836
#
#      high_q50_pct_error  high_q50_abs_pct_error  high_q50_accuracy  \
# 0                   NaN                     NaN                  0
# 1              0.437022                0.437022                  0
# 2             -0.425409                0.425409                  1
# 3              0.618335                0.618335                  0
# 4              0.427718                0.427718                  0
# ..                  ...                     ...                ...
# 632           -0.640373                0.640373                  1
# 633           -0.497457                0.497457                  1
# 634           -0.651383                0.651383                  1
# 635           -0.886116                0.886116                  1
# 636           -0.524722                0.524722                  1
#
#      low_q50_error  low_q50_abs_error  low_q50_pct_error  \
# 0        -0.009335           0.009335                NaN
# 1        -0.005626           0.005626          -0.464502
# 2         0.000275           0.000275           0.022675
# 3        -0.008973           0.008973          -0.752284
# 4        -0.006278           0.006278          -0.530670
# ..             ...                ...                ...
# 632       0.006107           0.006107           0.559300
# 633       0.002497           0.002497           0.228888
# 634       0.004298           0.004298           0.392611
# 635       0.007885           0.007885           0.710916
# 636       0.005878           0.005878           0.528508
#
#      low_q50_abs_pct_error  low_q50_accuracy
# 0                      NaN                 0
# 1                 0.464502                 1
# 2                 0.022675                 0
# 3                 0.752284                 1
# 4                 0.530670                 1
# ..                     ...               ...
# 632               0.559300                 0
# 633               0.228888                 0
# 634               0.392611                 0
# 635               0.710916                 0
# 636               0.528508                 0
#
# [637 rows x 11 columns]

# %%
from src.eval.plots import *

d,t = prepare_summary_reports(abnormal_metric)
t.show()
# Out:
# <div>                            <div id="2198ce85-58ee-4f63-9bd0-3693464867f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2198ce85-58ee-4f63-9bd0-3693464867f7")) {                    Plotly.newPlot(                        "2198ce85-58ee-4f63-9bd0-3693464867f7",                        [{"cells":{"align":"left","values":[["count","mean","std","min","25%","50%","75%","max"],[637.0,0.0068,0.002,0.005,0.0055,0.0062,0.0075,0.0229],[637.0,0.0052,0.003,0.0,0.0032,0.0051,0.0067,0.02]]},"header":{"align":"left","font":{"size":10},"values":["index","high_q50_abs_error","low_q50_abs_error"]},"type":"table","domain":{"x":[0.0,1.0],"y":[0.55,1.0]}},{"cells":{"align":"left","values":[["count","mean","std","min","25%","50%","75%","max"],[637.0,0.7268,0.4459,0.0,0.0,1.0,1.0,1.0],[637.0,0.3108,0.4632,0.0,0.0,0.0,1.0,1.0]]},"header":{"align":"left","font":{"size":10},"values":["index","high_q50_accuracy","low_q50_accuracy"]},"type":"table","domain":{"x":[0.0,1.0],"y":[0.0,0.45]}}],                        {"annotations":[{"font":{"size":16},"showarrow":false,"text":"Report 1: MAE summary","x":0.5,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"Report 2: Forecasting Accuracy summary","x":0.5,"xanchor":"center","xref":"paper","y":0.45,"yanchor":"bottom","yref":"paper"}],"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0 ...

# %%
from src.eval.plots import *
def generate_warning(metric):
    

    df_group_dict, fig = prepare_summary_reports(metric)

    
    df_group_1 = df_group_dict['df_group_1']
    print("Report 1 - Mean Absolute Error and Accuracy:")
    print("Mean Absolute Error (high_bid):", df_group_1.iloc[1, 1])
    print("Mean Absolute Error (low_ask):", df_group_1.iloc[1, 2])

    
    df_group_2 = df_group_dict['df_group_2']
    print("Report 2 - Mean Absolute Error and Accuracy:")
    print("Accuracy (high_bid):", df_group_2.iloc[1, 1])
    print("Accuracy (low_ask):", df_group_2.iloc[1, 2])

# %%
generate_warning(abnormal_metric)
# Out:
# Report 1 - Mean Absolute Error and Accuracy:
# Mean Absolute Error (high_bid): 0.0068
# Mean Absolute Error (low_ask): 0.0052
# Report 2 - Mean Absolute Error and Accuracy:
# Accuracy (high_bid): 0.7268
# Accuracy (low_ask): 0.3108

# %%
generate_warning(normal_metric)
# Out:
# Report 1 - Mean Absolute Error and Accuracy:
# Mean Absolute Error (high_bid): 0.0011
# Mean Absolute Error (low_ask): 0.0011
# Report 2 - Mean Absolute Error and Accuracy:
# Accuracy (high_bid): 0.4218
# Accuracy (low_ask): 0.4406

# %%
generate_warning(general_metric)
# Out:
# Report 1 - Mean Absolute Error and Accuracy:
# Mean Absolute Error (high_bid): 0.0012
# Mean Absolute Error (low_ask): 0.0012
# Report 2 - Mean Absolute Error and Accuracy:
# Accuracy (high_bid): 0.4277
# Accuracy (low_ask): 0.4381
